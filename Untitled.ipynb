# %%
#Inicializacion
import folium
import requests
import xml.etree.ElementTree as ET
import base64
from BaseXClient import BaseXClient
import tkinter as tk
import webbrowser
from folium.plugins import Fullscreen
import os
import webview
from tkhtmlview import HTMLLabel
from tkinter import Tk
from tkinter.filedialog import askopenfilename

# %%
def cargaDB(lat1, lon1, lat2, lon2, session):
  # URL de la API de OSM
  url = f"https://api.openstreetmap.org/api/0.6/map?bbox={lat1},{lon1},{lat2},{lon2}"

  # Hacer la solicitud HTTP GET
  response = requests.get(url)

  # Verificar el código de estado de la respuesta
  if response.status_code == 200:
      # Decodificar la respuesta en formato XML
      osm_data = ET.fromstring(response.content)

      try:
        # Crear una base de datos en BaseX
        session.execute("create db osm")
        
        # convertir el objeto Element a una cadena
        osm_data_str = ET.tostring(osm_data, encoding="unicode", method="xml")

        # Añadir el contenido XML a la base de datos
        session.add("osm", osm_data_str)

        # Imprimir un mensaje de confirmación
        print("Mapa OSM cargado en BaseX")
      except Exception as e:
          # Imprimir un mensaje de error si hay un problema
          print("Error al cargar el mapa OSM en BaseX:", e)

  else:
      print("Error al descargar el mapa OSM")

# %%
def cargaDB2(session):
    
    session.execute("create db osm")
    
    try:
        with open('MT-OSM-master\TAGS\datasets\Madrid\map.osm', 'rb') as f:
            contenido = f.read()
            session.add("map.osm", contenido.decode())
        # Imprimir un mensaje de confirmación
        print("Mapa OSM cargado en BaseX")
    except Exception as e:
          # Imprimir un mensaje de error si hay un problema
          print("Error al cargar el mapa OSM en BaseX:", e)

# %%
# Crea un mapa centrado en una ubicación y con un nivel de zoom inicial
mapa = folium.Map(location=[37.7749, -3], zoom_start=12)

# Agrega los datos de OSM al mapa
folium.TileLayer('openstreetmap').add_to(mapa)

# %%
#Función dado un id de NODO, calcula su latitud y longitud
def latandlon(id):
  url = f"https://api.openstreetmap.org/api/0.6/node/{id}"
  response = requests.get(url)
  root = ET.fromstring(response.content)
  node = root.find("node")
  lat = node.attrib["lat"]
  lon = node.attrib["lon"]

  return lat, lon

# %%
import os

path = 'MT-OSM-master\GEOMETRY\src\mt-osm-geometry.xqm'

if os.path.exists(path):
    print(path)
else:
    print('El archivo no existe en la ubicación especificada.')
# Out:
# MT-OSM-master\GEOMETRY\src\mt-osm-geometry.xqm

# %%
session = BaseXClient.Session('localhost', 1984, 'admin', 'admin')


cargaDB(40.428706, -3.689491, 40.432154, -3.668299, session)
print("\n" + session.execute("xquery doc('osm')"))

session.close()
# Out:
# Mapa OSM cargado en BaseX
#
# <osm version="0.6" generator="CGImap 0.8.8 (3770663 spike-08.openstreetmap.org)" copyright="OpenStreetMap and contributors" attribution="http://www.openstreetmap.org/copyright" license="http://opendatacommons.org/licenses/odbl/1-0/">
#  <bounds minlat="-3.6894910" minlon="40.4287060" maxlat="-3.6682990" maxlon="40.4321540"/>
# </osm>

# %%
session.close()

# %%
def marcaPuntos(result, mapa):
    #Compacta el string en un xml
    xml_string = '<errores>' + result + '</errores>'
    
    root = ET.fromstring(xml_string)
    
    #Busca todas las ways
    ways = root.findall('.//way')
    
    #Por cada way, encuentra el primer nodo y lo marca en el mapa
    for w in ways:
        nd_element = w.find('./nd').get('ref')
        lat, lon= latandlon(nd_element)
        
        #Marca un punto en el mapa dado una [latitud, longitud]
        folium.Marker(location=[lat, lon], popup="NoDeadlockTest").add_to(mapa)
        
    return xml_string

# %%
def generar_mapa():
    # Crear mapa de Folium
    mapa = folium.Map(location=[40.4168, -3.7038], zoom_start=13)

    # Añadir marcador
    folium.Marker([40.4168, -3.7038], popup='Madrid').add_to(mapa)

    # Guardar archivo HTML del mapa
    mapa.save('mapa.html')
    
ventana = tk.Tk()
ventana.geometry("500x500")

generar_mapa()
    
html_label = HTMLLabel(ventana, html=os.path.realpath("map.html"))
html_label.pack()

# Ejecutar aplicación
ventana.mainloop()

# %%
def generar_mapa():
    # Crear mapa de Folium
    mapa = folium.Map(location=[40.4168, -3.7038], zoom_start=13)

    # Añadir marcador
    folium.Marker([40.4168, -3.7038], popup='Madrid').add_to(mapa)

    # Guardar archivo HTML del mapa
    mapa.save('mapa.html')
    
def open_map():
    hola = webview.create_window("Mapa", os.path.realpath("mapa.html"))
    return hola

ventana = tk.Tk()
ventana.geometry("800x800")

generar_mapa()

with open(os.path.realpath("mapa.html"), 'r') as f:
    html = f.read()
    
html_label = HTMLLabel(ventana, html=html)
html_label.pack()

ventana.mainloop()

# %%
from PyQt5.QtCore import *
from PyQt5.QtWidgets import *
from PyQt5.QtWebEngineWidgets import *
import os

class MainWindow(QMainWindow):
    def __init__(self):
        super().__init__()

        # Crear un WebView
        self.webview = QWebEngineView()
        self.setCentralWidget(self.webview)

        # Cargar un archivo HTML local
        self.webview.load(QUrl.fromLocalFile(os.path.realpath("mapa.html")))
        
def generar_mapa():
    # Crear mapa de Folium
    mapa = folium.Map(location=[40.4168, -3.7038], zoom_start=13)

    # Añadir marcador
    folium.Marker([40.4168, -3.7038], popup='Madrid').add_to(mapa)

    # Guardar archivo HTML del mapa
    mapa.save('mapa.html')
    
generar_mapa()
    
if __name__ == '__main__':
    app = QApplication([])
    window = MainWindow()
    window.show()
    app.exec_()

# %%
from PyQt5.QtWidgets import QApplication, QWidget, QVBoxLayout
from PyQt5.QtCore import QUrl
from PyQt5.QtWebEngineWidgets import QWebEngineView
import os

def generar_mapa():
    # Crear mapa de Folium
    mapa = folium.Map(location=[40.4168, -3.7038], zoom_start=13)

    # Añadir marcador
    folium.Marker([40.4168, -3.7038], popup='Madrid').add_to(mapa)

    # Guardar archivo HTML del mapa
    mapa.save('mapa.html')
    
generar_mapa()
app = QApplication([])
window = QWidget()
window.setWindowTitle("Mi aplicación de WebView")

view = QWebEngineView()
view.load(QUrl.fromLocalFile(os.path.realpath("mapa.html")))

layout = QVBoxLayout()
layout.addWidget(view)
window.setLayout(layout)

window.show()
app.exec_()
# Out:
# 0

# %%
def cargaDBdadoUnMapa(session, mapGiven):

    
    session.execute("create db osm")
    
    try:
        with open(mapGiven, 'rb') as f:
            contenido = f.read()
            session.add("map.osm", contenido.decode())
        # Imprimir un mensaje de confirmación
        print("Mapa OSM cargado en BaseX")
    except Exception as e:
          # Imprimir un mensaje de error si hay un problema
          print("Error al cargar el mapa OSM en BaseX:", e)

# %%
def meterMapa(session):
    # Seleccionar archivo
    raiz = Tk()
    raiz.withdraw()
    mapGiven = askopenfilename()
    
    # Carga el mapa dado el mapa seleccionado
    cargaDBdadoUnMapa(session, mapGiven)

# %%
session = BaseXClient.Session('localhost', 1984, 'admin', 'admin')
meterMapa(session)
session.close()
# Out:
# Mapa OSM cargado en BaseX

# %%
def posicionarMapaConCalle(direccion):
    # Convertir la dirección a coordenadas utilizando la API de OSM
    respuesta = requests.get("https://nominatim.openstreetmap.org/search",
                         params={"q": direccion, "format": "json"})
    resultado = respuesta.json()[0] # Tomamos la primera coincidencia
    
    # Mete las coordenadas al mapa
    mapa = folium.Map(location=[resultado["lat"], resultado["lon"]], zoom_start=13)

# %%
def cargaOSMGeometry(session):
    module_namespace = 'mt'
    module_path = 'MT-OSM-master\GEOMETRY\src\mt-osm-geometry.xqm'
    inp = f"import module namespace mt = '{module_namespace}' at '{module_path}';"

    
    inp += 'mt:NoDeadlockTest(.,"",())'
    print(inp)
    result = session.query(inp)
    r = result.execute()
    return r

# %%
def MtGeometry(session, func):
    module_namespace = 'mt'
    module_path = 'MT-OSM-master\GEOMETRY\src\mt-osm-geometry.xqm'
    inp = f"import module namespace mt = '{module_namespace}' at '{module_path}';"
    
    inp += 'mt:' + func + '(.,"",())'
    result = session.query(inp)
    r = result.execute()
    return r

# %%
#establece una conexión
session = BaseXClient.Session('localhost', 1984, 'admin', 'admin')
#Carga la base de datos en BASEX
cargaDB2(session)

#Realiza la consulta NoDeadlockTest
result = cargaOSMGeometry(session)

# Marca los puntos que se hayan devuelto de la consulta
marcaPuntos(result, mapa)

    
#Centra en los puntos que haya
mapa.fit_bounds(mapa.get_bounds())
# Muestra el mapa
mapa
# Out:
# Mapa OSM cargado en BaseX
# import module namespace mt = 'mt' at 'MT-OSM-master\GEOMETRY\src\mt-osm-geometry.xqm';mt:NoDeadlockTest(.,"",())
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6578c995fda5563c99b79bfac97adff0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6578c995fda5563c99b79bfac97adff0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6578c995fda5563c99b79bfac97adff0 = L.map(
#                 &quot;map_6578c995fda5563c99b79bfac97adff0&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ddb1428da583ac3ad71aab853752647b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6578c995fda5563c99b79bfac97adff0);
#
#
#             var marker_a9a2a86bf552b1caee483e2c844aa145 = L.marker(
#                 [40.430296, -3.6836996],
#                 {}
#             ).addTo(map_6578c995fda5563c99b79bfac97adff0);
#
#
#         var popup_b296b8acad5b04fda0661324ca427030 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_03daf52645187e854008f0388d390850 = $(`&lt;div id=&quot;html_03daf52645187e854008f0388d390850&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NoDeadlockTest&lt;/div&gt;`)[0];
#                 popup_b296b8acad5b04fda0661324ca427030.setContent(html_03daf52645187e854008f0388d390850);
#
#
#
#         marker_a9a2a86bf552b1caee483e2c844aa145.bindPopup(popup_b296b8acad5b04fda0661324ca427030)
#         ;
#
#
#
#
#             var marker_fb1924fb17d158d35320eee99c612c84 = L.marker(
#                 [40.4296647, -3.6705685],
#                 {}
#             ).addTo(map_6578c995fda5563c99b79bfac97adff0);
#
#
#         var popup_3e73f8d730e6cb1ab8acf1720b1acf32 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7dbc0767bf8f98f03d0307c9f6229465 = $(`&lt;div id=&quot;html_7dbc0767bf8f98f03d0307c9f6229465&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NoDeadlockTest&lt;/div&gt;`)[0];
#                 popup_3e73f8d730e6cb1ab8acf1720b1acf32.setContent(html_7dbc0767bf8f98f03d0307c9f6229465);
#
#
#
#         marker_fb1924fb17d158d35320eee99c612c84.bindPopup(popup_3e73f8d730e6cb1ab8acf1720b1acf32)
#         ;
#
#
#
#
#             var marker_80fbc3ff186c93910811e6085a1b20ab = L.marker(
#                 [40.4302723, -3.6801316],
#                 {}
#             ).addTo(map_6578c995fda5563c99b79bfac97adff0);
#
#
#         var popup_9e14e9b669d5df20d479e07e8c832d71 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_77b68af024698001a0fa56b9202b9ceb = $(`&lt;div id=&quot;html_77b68af024698001a0fa56b9202b9ceb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NoDeadlockTest&lt;/div&gt;`)[0];
#                 popup_9e14e9b669d5df20d479e07e8c832d71.setContent(html_77b68af024698001a0fa56b9202b9ceb);
#
#
#
#         marker_80fbc3ff186c93910811e6085a1b20ab.bindPopup(popup_9e14e9b669d5df20d479e07e8c832d71)
#         ;
#
#
#
#
#             var marker_020874c36f0b82ad99a3e2e3ed5efad3 = L.marker(
#                 [40.4299524, -3.679349],
#                 {}
#             ).addTo(map_6578c995fda5563c99b79bfac97adff0);
#
#
#         var popup_71ebb44c73494c493cce755d3f4945e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_62f09b94bbf9a8b21bd5b7c7b876330e = $(`&lt;div id=&quot;html_62f09b94bbf9a8b21bd5b7c7b876330e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NoDeadlockTest&lt;/div&gt;`)[0];
#                 popup_71ebb44c73494c493cce755d3f4945e1.setContent(html_62f09b94bbf9a8b21bd5b7c7b876330e);
#
#
#
#         marker_020874c36f0b82ad99a3e2e3ed5efad3.bindPopup(popup_71ebb44c73494c493cce755d3f4945e1)
#         ;
#
#
#
#
#             var marker_ea319e99df30f2c76783ddbed115ff82 = L.marker(
#                 [40.4301453, -3.6804188],
#                 {}
#             ).addTo(map_6578c995fda5563c99b79bfac97adff0);
#
#
#         var popup_39fb46f7bcddf48a3ffb2f2036ca2442 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0e9ef78918b198c248b305d3b36c5997 = $(`&lt;div id=&quot;html_0e9ef78918b198c248b305d3b36c5997&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NoDeadlockTest&lt;/div&gt;`)[0];
#                 popup_39fb46f7bcddf48a3ffb2f2036ca2442.setContent(html_0e9ef78918b198c248b305d3b36c5997);
#
#
#
#         marker_ea319e99df30f2c76783ddbed115ff82.bindPopup(popup_39fb46f7bcddf48a3ffb2f2036ca2442)
#         ;
#
#
#
#
#             var marker_4acd514d3ff91f356846312a8af316e6 = L.marker(
#                 [40.4300719, -3.6790675],

# %%
session = BaseXClient.Session('localhost', 1984, 'admin', 'admin')
mapa = folium.Map(location=[40.4168, -3.7038], zoom_start=13)
cargaDB2(session)
r = MtGeometry(session, 'NoDeadlockTest')
marcaPuntos(r, mapa)
session.close()
mapa.fit_bounds(mapa.get_bounds())
mapa
# Out:
# Mapa OSM cargado en BaseX
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1a61a4f6524f467bba5baa22097067a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1a61a4f6524f467bba5baa22097067a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1a61a4f6524f467bba5baa22097067a = L.map(
#                 &quot;map_c1a61a4f6524f467bba5baa22097067a&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_342fc3fde8af507323ba14dcdc38a812 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c1a61a4f6524f467bba5baa22097067a);
#
#
#             var marker_a0945fac22a1d144196e7e349f73187e = L.marker(
#                 [40.430296, -3.6836996],
#                 {}
#             ).addTo(map_c1a61a4f6524f467bba5baa22097067a);
#
#
#         var popup_cd6f3bb7aada31d36deaa02c3a2e0812 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_443fffdb97bc0fab59f8147382eb10f8 = $(`&lt;div id=&quot;html_443fffdb97bc0fab59f8147382eb10f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NoDeadlockTest&lt;/div&gt;`)[0];
#                 popup_cd6f3bb7aada31d36deaa02c3a2e0812.setContent(html_443fffdb97bc0fab59f8147382eb10f8);
#
#
#
#         marker_a0945fac22a1d144196e7e349f73187e.bindPopup(popup_cd6f3bb7aada31d36deaa02c3a2e0812)
#         ;
#
#
#
#
#             var marker_6556612d348a898957609dc78e4a2b74 = L.marker(
#                 [40.4296647, -3.6705685],
#                 {}
#             ).addTo(map_c1a61a4f6524f467bba5baa22097067a);
#
#
#         var popup_0238bdebd2022ecbc14452df8c07b3f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dc7908a0f90a017649a7b778d55e4a07 = $(`&lt;div id=&quot;html_dc7908a0f90a017649a7b778d55e4a07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NoDeadlockTest&lt;/div&gt;`)[0];
#                 popup_0238bdebd2022ecbc14452df8c07b3f6.setContent(html_dc7908a0f90a017649a7b778d55e4a07);
#
#
#
#         marker_6556612d348a898957609dc78e4a2b74.bindPopup(popup_0238bdebd2022ecbc14452df8c07b3f6)
#         ;
#
#
#
#
#             var marker_9d973fe7c3ea54ff96b545f37d9acd2b = L.marker(
#                 [40.4302723, -3.6801316],
#                 {}
#             ).addTo(map_c1a61a4f6524f467bba5baa22097067a);
#
#
#         var popup_155104080ce9b2d2ad0bba3d87a8947f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_578a83d8926374166d8ef06e561333ac = $(`&lt;div id=&quot;html_578a83d8926374166d8ef06e561333ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NoDeadlockTest&lt;/div&gt;`)[0];
#                 popup_155104080ce9b2d2ad0bba3d87a8947f.setContent(html_578a83d8926374166d8ef06e561333ac);
#
#
#
#         marker_9d973fe7c3ea54ff96b545f37d9acd2b.bindPopup(popup_155104080ce9b2d2ad0bba3d87a8947f)
#         ;
#
#
#
#
#             var marker_923d93dadbbd681641dda15504fd64b6 = L.marker(
#                 [40.4299524, -3.679349],
#                 {}
#             ).addTo(map_c1a61a4f6524f467bba5baa22097067a);
#
#
#         var popup_946b750c88fbef0ecf6c41feb5d56299 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a0823c1c57d75d22e8dd3d51b649fa0b = $(`&lt;div id=&quot;html_a0823c1c57d75d22e8dd3d51b649fa0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NoDeadlockTest&lt;/div&gt;`)[0];
#                 popup_946b750c88fbef0ecf6c41feb5d56299.setContent(html_a0823c1c57d75d22e8dd3d51b649fa0b);
#
#
#
#         marker_923d93dadbbd681641dda15504fd64b6.bindPopup(popup_946b750c88fbef0ecf6c41feb5d56299)
#         ;
#
#
#
#
#             var marker_ead8fd3bf90ccab9240bf01e6c4f4632 = L.marker(
#                 [40.4301453, -3.6804188],
#                 {}
#             ).addTo(map_c1a61a4f6524f467bba5baa22097067a);
#
#
#         var popup_0aaa18bdba3e639c7264c0156f8a5b66 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8fe020b7133f010fde2f57e02282d67a = $(`&lt;div id=&quot;html_8fe020b7133f010fde2f57e02282d67a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NoDeadlockTest&lt;/div&gt;`)[0];
#                 popup_0aaa18bdba3e639c7264c0156f8a5b66.setContent(html_8fe020b7133f010fde2f57e02282d67a);
#
#
#
#         marker_ead8fd3bf90ccab9240bf01e6c4f4632.bindPopup(popup_0aaa18bdba3e639c7264c0156f8a5b66)
#         ;
#
#
#
#
#             var marker_9eb10978e1f3d8eac8a8769cd62bff50 = L.marker(
#                 [40.4300719, -3.6790675],

# %%
def dibujarArea(coordenadas, m):
    i = 1
    for i in range(len(coordenadas)):
        if i == len(coordenadas) - 1:
            folium.PolyLine(locations=[coordenadas[i], coordenadas[0]]).add_to(m)
        folium.PolyLine(locations=[coordenadas[i], coordenadas[i-1]]).add_to(m)
        i+=1

# %%
import folium

# Crear un mapa centrado en Madrid
madrid = (40.4168, -3.7038)
m = folium.Map(location=madrid, zoom_start=6)

coordenadas = []
coordenadas.append((40.4168, -3.7038))
coordenadas.append((41.3851, 2.1734))
coordenadas.append((42.4168, -3.7038))

print(coordenadas)
dibujarArea(coordenadas, m)

m
# Out:
# [(40.4168, -3.7038), (41.3851, 2.1734), (42.4168, -3.7038)]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba158a4c9771e50ffdfd3eb253807e52 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba158a4c9771e50ffdfd3eb253807e52&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba158a4c9771e50ffdfd3eb253807e52 = L.map(
#                 &quot;map_ba158a4c9771e50ffdfd3eb253807e52&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7506bd7aa4c9cd74192986f41a25691 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ba158a4c9771e50ffdfd3eb253807e52);
#
#
#             var poly_line_92df9c27e23f56afa6257d01851d36e7 = L.polyline(
#                 [[40.4168, -3.7038], [42.4168, -3.7038]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ba158a4c9771e50ffdfd3eb253807e52);
#
#
#             var poly_line_84c011fb5b2b8b8df52d42e75bc6de4e = L.polyline(
#                 [[41.3851, 2.1734], [40.4168, -3.7038]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ba158a4c9771e50ffdfd3eb253807e52);
#
#
#             var poly_line_21d8a42aa6613b2159c024d47a647a3a = L.polyline(
#                 [[42.4168, -3.7038], [40.4168, -3.7038]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ba158a4c9771e50ffdfd3eb253807e52);
#
#
#             var poly_line_97f0e7f6d2f19d33d3c5605f7241b551 = L.polyline(
#                 [[42.4168, -3.7038], [41.3851, 2.1734]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ba158a4c9771e50ffdfd3eb253807e52);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Coordenadas de los dos puntos que queremos unir con una línea
punto1 = (40.4168, -3.7038)
punto2 = (41.3851, 2.1734)
punto3 = (42.4168, -3.7038)

# Crear un mapa centrado en Madrid
madrid = (40.4168, -3.7038)
m = folium.Map(location=madrid, zoom_start=6)

# Dibujar una línea entre los dos puntos
folium.PolyLine(locations=[punto1, punto2]).add_to(m)
folium.PolyLine(locations=[punto1, punto3]).add_to(m)
folium.PolyLine(locations=[punto3, punto2]).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9e700f982111baaf29fb9546ab1e40d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9e700f982111baaf29fb9546ab1e40d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9e700f982111baaf29fb9546ab1e40d = L.map(
#                 &quot;map_d9e700f982111baaf29fb9546ab1e40d&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_64e51515c92fd486fbbcfefc8b0fe4c6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d9e700f982111baaf29fb9546ab1e40d);
#
#
#             var poly_line_4e62b4f20ea36cbc95ca06d6c27859c5 = L.polyline(
#                 [[40.4168, -3.7038], [41.3851, 2.1734]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d9e700f982111baaf29fb9546ab1e40d);
#
#
#             var poly_line_74f8584566aa191acea68874950260df = L.polyline(
#                 [[40.4168, -3.7038], [42.4168, -3.7038]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d9e700f982111baaf29fb9546ab1e40d);
#
#
#             var poly_line_7544940b42db3d465e6989a88adddb04 = L.polyline(
#                 [[42.4168, -3.7038], [41.3851, 2.1734]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d9e700f982111baaf29fb9546ab1e40d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# crear un objeto de mapa
m = folium.Map(location=[51.5074, -0.1278], zoom_start=12)

# agregar algunos marcadores al mapa
folium.Marker(location=[51.5074, -0.1278]).add_to(m)
folium.Marker(location=[51.5007, -0.1246]).add_to(m)
folium.Marker(location=[51.5111, -0.1198]).add_to(m)

# obtener un diccionario que representa todos los elementos en el mapa
map_dict = m.to_dict()

# inicializar una lista para almacenar las ubicaciones de los marcadores
marker_locations = []

# buscar los elementos que sean marcadores y obtener sus ubicaciones
for element in map_dict['children']:
    print(element)
    if 'marker' in element:
        print("hola")
        marker_locations.append(m.get_name_lat_lon(element)[1:])

# imprimir la lista de ubicaciones de los marcadores
for location in marker_locations:
    print(location)
# Out:
# openstreetmap
# marker_1148211db18a25d436ef6d43ea59ffd1
# hola
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [38], line 22
#      20     if 'marker' in element:
#      21         print("hola")
# ---> 22         marker_locations.append(m.get_name_lat_lon(element)[1:])
#      24 # imprimir la lista de ubicaciones de los marcadores
#      25 for location in marker_locations:
#
# AttributeError: 'Map' object has no attribute 'get_name_lat_lon'

# %%
import folium

# crear un objeto de mapa
m = folium.Map(location=[51.5074, -0.1278], zoom_start=12)

# agregar un marcador al mapa con un nombre específico
folium.Marker(location=[51.5111, -0.1198]).add_to(m)
folium.Marker(location=[51, -0.1]).add_to(m)

marker_locations = []

print(m._children.values())
for child in m._children.values():
    if isinstance(child, folium.Marker):
        marker_locations.append(child.location)

if marker_locations:
    print(marker_locations)
else:
    print("No se encontraron marcadores en el mapa.")
# Out:
# odict_values([<folium.raster_layers.TileLayer object at 0x000002331717C6A0>, <folium.map.Marker object at 0x0000023317102380>, <folium.map.Marker object at 0x000002331716E4A0>])
# [[51.5111, -0.1198], [51.0, -0.1]]

# %%
import folium

# Crear un mapa centrado en Madrid
madrid = (40.4168, -3.7038)
m = folium.Map(location=madrid, zoom_start=13)

m.add_child(folium.ClickForMarker())

marker_locations = []
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_21dd5867e31aa5b2870f4629d3162dbe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_21dd5867e31aa5b2870f4629d3162dbe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_21dd5867e31aa5b2870f4629d3162dbe = L.map(
#                 &quot;map_21dd5867e31aa5b2870f4629d3162dbe&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e893001608907cb67b95414b6fd9486 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_21dd5867e31aa5b2870f4629d3162dbe);
#
#
#                 function newMarker(e){
#                     var new_mark = L.marker().setLatLng(e.latlng).addTo(map_21dd5867e31aa5b2870f4629d3162dbe);
#                     new_mark.dragging.enable();
#                     new_mark.on(&#x27;dblclick&#x27;, function(e){ map_21dd5867e31aa5b2870f4629d3162dbe.removeLayer(e.target)})
#                     var lat = e.latlng.lat.toFixed(4),
#                        lng = e.latlng.lng.toFixed(4);
#                     new_mark.bindPopup(&quot;Latitude: &quot; + lat + &quot;&lt;br&gt;Longitude: &quot; + lng );
#                     };
#                 map_21dd5867e31aa5b2870f4629d3162dbe.on(&#x27;click&#x27;, newMarker);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
m = folium.Map(location=[40.7128, -74.0060], zoom_start=12)

# agregar una capa GeoJson vacía para almacenar los marcadores
marker_layer = folium.FeatureGroup(name="markers")
m.add_child(marker_layer)

# agregar una función ClickForMarker para que los usuarios puedan agregar marcadores
marker_layer.add_child(folium.ClickForMarker())

# guardar el mapa como un archivo HTML
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_62c828853e76607cc5c7657c25a78153 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_62c828853e76607cc5c7657c25a78153&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_62c828853e76607cc5c7657c25a78153 = L.map(
#                 &quot;map_62c828853e76607cc5c7657c25a78153&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dcfce59809164b9b09ecab9eaf3d958a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_62c828853e76607cc5c7657c25a78153);
#
#
#             var feature_group_f3977b975905bbcedebf885a0065188a = L.featureGroup(
#                 {}
#             ).addTo(map_62c828853e76607cc5c7657c25a78153);
#
#
#                 function newMarker(e){
#                     var new_mark = L.marker().setLatLng(e.latlng).addTo(feature_group_f3977b975905bbcedebf885a0065188a);
#                     new_mark.dragging.enable();
#                     new_mark.on(&#x27;dblclick&#x27;, function(e){ feature_group_f3977b975905bbcedebf885a0065188a.removeLayer(e.target)})
#                     var lat = e.latlng.lat.toFixed(4),
#                        lng = e.latlng.lng.toFixed(4);
#                     new_mark.bindPopup(&quot;Latitude: &quot; + lat + &quot;&lt;br&gt;Longitude: &quot; + lng );
#                     };
#                 feature_group_f3977b975905bbcedebf885a0065188a.on(&#x27;click&#x27;, newMarker);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
from PyQt5.QtWidgets import QApplication, QWidget, QVBoxLayout, QPushButton, QMainWindow, QDesktopWidget
from PyQt5.QtWebEngineWidgets import QWebEngineView
import sys
import tkinter as tk
from tkinter import *
from PIL import ImageTk, Image
import PyQt5

from PyQt5.QtWidgets import QApplication, QWidget, QVBoxLayout, QListWidget, QHBoxLayout, QGridLayout,QCheckBox, QPushButton
from PyQt5.QtCore import QUrl
from PyQt5.QtWebEngineWidgets import QWebEngineView
import os

class VentanaMapa(QMainWindow):
    def __init__(self):
        super().__init__()

        # Configurar la ventana principal
        self.setWindowTitle('Mapa')
        self.resize(800, 600)

        # Centrar la ventana en la pantalla
        centro = QDesktopWidget().availableGeometry().center()
        self.move(centro - self.rect().center())

        # Crear el mapa con folium y guardarlo en un archivo HTML
        self.generar_mapa()

        # Crear un objeto QWebEngineView para mostrar el mapa HTML
        self.web_view = QWebEngineView()
        self.setCentralWidget(self.web_view)

        # Cargar el archivo HTML en el objeto QWebEngineView
        self.web_view.load(QUrl.fromLocalFile(os.path.realpath("mapa.html")))

    def generar_mapa(self):
        mapa = folium.Map(location=[40.4168, -3.7038], zoom_start=13)
        folium.Marker([40.4168, -3.7038], popup='Madrid').add_to(mapa)
        mapa.save('mapa.html')


class VentanaPrincipal(QWidget):
    def __init__(self):
        super().__init__()

        # Configurar la ventana principal
        self.setWindowTitle('Ventana principal')
        self.resize(200, 100)

        # Crear el botón y añadirlo al layout vertical
        layout = QVBoxLayout(self)
        boton = QPushButton('Mostrar mapa', self)
        layout.addWidget(boton)

        # Conectar la señal clicked del botón a la función mostrar_mapa
        boton.clicked.connect(self.mostrar_mapa)

    def mostrar_mapa(self):
        # Crear una instancia de la ventana del mapa y mostrarla
        ventana_mapa = VentanaMapa()
        ventana_mapa.show()


if __name__ == '__main__':
    app = QApplication(sys.argv)

    # Crear una instancia de la ventana principal y mostrarla
    ventana_principal = VentanaPrincipal()
    ventana_principal.show()
    ventana_mapa = VentanaMapa()
    ventana_mapa.show()

    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\Tyson\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:3386: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
from PyQt5.QtWidgets import QApplication, QWidget, QVBoxLayout, QListWidget, QHBoxLayout, QGridLayout,QCheckBox, QPushButton
from PyQt5.QtCore import QUrl
from PyQt5.QtWebEngineWidgets import QWebEngineView
import os

def generar_mapa():
    # Crear mapa de Folium
    mapa = folium.Map(location=[40.4168, -3.7038], zoom_start=13)

    # Añadir marcador
    folium.Marker([40.4168, -3.7038], popup='Madrid').add_to(mapa)

    # Guardar archivo HTML del mapa
    mapa.save('mapa.html')
    
    
def ventanaMapa():    
    generar_mapa()
    app = QApplication([])
    window = QWidget()
    window.setWindowTitle("Mi aplicación de WebView")

    view = QWebEngineView()
    view.load(QUrl.fromLocalFile(os.path.realpath("mapa.html")))

    layout = QVBoxLayout()
    layout.addWidget(view)
    window.setLayout(layout)

    window.show()
    
def ventanaInicio():
    app = QApplication([])
    window = QWidget()
    window.setWindowTitle("Mi aplicación de WebView")
    
    layout = QVBoxLayout()
    window.setLayout(layout)
    boton = QPushButton('Mostrar mapa')
    layout.addWidget(boton)
    boton.clicked.connect(ventanaMapa())
    
    window.show()
    app.exec_()
    
ventanaInicio()

# %%
from PyQt5.QtWidgets import QApplication, QWidget, QVBoxLayout, QListWidget, QHBoxLayout, QGridLayout,QCheckBox, QPushButton
from PyQt5.QtCore import QUrl
from PyQt5.QtWebEngineWidgets import QWebEngineView
import os

def ventanaInicio():
    app = QApplication([])
    window = QWidget()
    window.setWindowTitle("Mi aplicación de WebView")
    
    layout = QVBoxLayout()
    window.setLayout(layout)
    boton = QPushButton('Mostrar mapa')
    layout.addWidget(boton)
    
    window.show()
    app.exec_()
    
ventanaInicio()
